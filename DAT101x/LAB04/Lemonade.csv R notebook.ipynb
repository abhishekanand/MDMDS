# %%
library("AzureML")
ws <- workspace()
dat <- download.datasets(ws, "Lemonade.csv")

# %%
head(dat)
# Out:
#   Date       Day       Temperature Rainfall Flyers Price Sales
# 1 01/01/2017 Sunday    27.0        2.00     15     0.3   10
# 2 02/01/2017 Monday    28.9        1.33     15     0.3   13
# 3 03/01/2017 Tuesday   34.5        1.33     27     0.3   15
# 4 04/01/2017 Wednesday 44.1        1.05     28     0.3   17
# 5 05/01/2017 Thursday  42.4        1.00     33     0.3   18
# 6 06/01/2017 Friday    25.3        1.54     23     0.3   11

# %%
# Print statistics for Temperature and Sales
summary(dat[c('Temperature', 'Sales')])
print('Standard Deviations:')
apply(dat[c('Temperature', 'Sales')],2,sd)

# Print correlation for temperature vs Sales
print('Correlation:')
cor(dat[c('Temperature', 'Sales')])

# Plot Temperature vs Sales
plot(dat$Temperature, dat$Sales, xlab="Temperature", ylab="Sales")
# Out:
#   Temperature         Sales
#  Min.   : 15.10   Min.   : 7.00
#  1st Qu.: 49.70   1st Qu.:20.00
#  Median : 61.10   Median :25.00
#  Mean   : 60.73   Mean   :25.32
#  3rd Qu.: 71.30   3rd Qu.:30.00
#  Max.   :102.90   Max.   :43.00
# [1] "Standard Deviations:"
# Temperature       Sales
#   16.196266    6.893589
# [1] "Correlation:"
#             Temperature Sales
# Temperature 1.0000000   0.9898321
# Sales       0.9898321   1.0000000
